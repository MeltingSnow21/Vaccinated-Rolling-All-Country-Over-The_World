# %% [markdown]
# import data

# %%
import pandas as pd

df = pd.read_excel(r'Vacciantion.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
df.head()
# Out:
#   iso_code continent     location        date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03    41128772          NaN
# 1      AFG      Asia  Afghanistan  2020-01-04    41128772          NaN
# 2      AFG      Asia  Afghanistan  2020-01-05    41128772          NaN
# 3      AFG      Asia  Afghanistan  2020-01-06    41128772          NaN
# 4      AFG      Asia  Afghanistan  2020-01-07    41128772          NaN
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  F58 F59  F60  \
# 0        0.0                 NaN           NaN         0.0  ...  NaN NaN  NaN
# 1        0.0                 NaN           NaN         0.0  ...  NaN NaN  NaN
# 2        0.0                 NaN           NaN         0.0  ...  NaN NaN  NaN
# 3        0.0                 NaN           NaN         0.0  ...  NaN NaN  NaN
# 4        0.0                 NaN           NaN         0.0  ...  NaN NaN  NaN
#
#    F61 F62  F63  F64 F65  F66 F67
# 0  NaN NaN  NaN  NaN NaN  NaN NaN
# ...

# %%
df2 = df.iloc[: ,[1,2,3,4,5,6]].copy()

# %%
df2= df2.fillna(0)
df2.drop(columns='new_cases')
# Out:
#            continent            location        date  population  total_cases
# 0               Asia         Afghanistan  2020-01-03    41128772          0.0
# 1               Asia         Afghanistan  2020-01-04    41128772          0.0
# 2               Asia         Afghanistan  2020-01-05    41128772          0.0
# 3               Asia         Afghanistan  2020-01-06    41128772          0.0
# 4               Asia         Afghanistan  2020-01-07    41128772          0.0
# ...              ...                 ...         ...         ...          ...
# 29893  North America  Dominican Republic  2020-05-27    11228821      15264.0
# 29894  North America  Dominican Republic  2020-05-28    11228821      15723.0
# 29895  North America  Dominican Republic  2020-05-29    11228821      16068.0
# 29896  North America  Dominican Republic  2020-05-30    11228821      16531.0
# 29897  North America  Dominican Republic  2020-05-31    11228821      16908.0
#
# [29898 rows x 5 columns]

# %%
grouped = df2.groupby('location')

df3 = grouped.mean()
df3.head()
# Out:
# C:\Users\a c e r\AppData\Local\Temp\ipykernel_21116\1901901041.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3 = grouped.mean()
#                   population   total_cases     new_cases
# location
# Afghanistan     4.112877e+07  1.283222e+05    165.003647
# Africa          1.426737e+09  6.603375e+06  11589.198222
# Albania         2.842318e+06  3.333822e+05      8.420054
# Algeria         4.490323e+07  0.000000e+00      0.000000
# American Samoa  4.429500e+04  0.000000e+00      0.000000

# %%
df3["lok"] = df3.index
df3.sort_values(by=['new_cases'], ascending=0).head(5)
# Out:
#                   population   total_cases      new_cases             lok
# location
# Europe          7.448078e+08  1.415244e+08  368692.298077          Europe
# Asia            4.721383e+09  6.587114e+07  263719.817308            Asia
# European Union  4.501468e+08  9.184295e+07  161981.326923  European Union
# Brazil          2.153135e+08  3.405959e+07   24859.413462          Brazil
# Australia       2.617741e+07  2.185910e+06   23545.583333       Australia

# %%
df3.index
# Out:
# Index(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bonaire Sint Eustatius and Saba', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'British Virgin Islands', 'Brunei', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada',
#        'Cape Verde', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Cote d'Ivoire', 'Croatia', 'Cuba', 'Curacao', 'Cyprus',
#        'Czechia', 'Democratic Republic of Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
# ...

# %%
df3.iloc[: ,2]
# Out:
# location
# Afghanistan                     165.003647
# Africa                        11589.198222
# Albania                           8.420054
# Algeria                           0.000000
# American Samoa                    0.000000
#                                   ...
# Kazakhstan                     3273.615385
# Mauritius                       257.336538
# Myanmar                         205.657051
# Saint Lucia                       0.000000
# Saint Martin (French part)        0.200000
# Name: new_cases, Length: 91, dtype: float64

# %%
df3.iloc[:10 ,2]
# Out:
# location
# Afghanistan              165.003647
# Africa                 11589.198222
# Albania                    8.420054
# Algeria                    0.000000
# American Samoa             0.000000
# Andorra                   49.175481
# Angola                   131.750000
# Anguilla                   1.185096
# Antigua and Barbuda        0.000000
# Argentina                 96.163121
# Name: new_cases, dtype: float64

# %%
import matplotlib.pyplot as plt
   

plt.bar(df3.iloc[:10 ,2], df3.iloc[:10 ,3])
plt.title('Country Vs GDP Per Capita')
plt.xlabel('Country')
plt.ylabel('GDP Per Capita')
plt.show()
